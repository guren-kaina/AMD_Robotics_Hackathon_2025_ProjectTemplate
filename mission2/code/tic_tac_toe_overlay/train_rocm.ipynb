# %% [markdown]
# # Train YOLOv8 for tic-tac-toe on ROCm

# %% [markdown]
# Prerequisites:
# - ROCm-ready PyTorch environment
# - This repo as current working directory
# - Optional: real/images and real/labels with manual annotations (use --real-data real)
#
# Adjust the commands to your environment as needed.

# %%
# Install ROCm PyTorch + dependencies (adjust for your ROCm version)
# !pip install --extra-index-url https://download.pytorch.org/whl/rocm6.0 torch torchvision torchaudio
# !pip install ultralytics opencv-python

# %%
# Check ROCm device
import torch
print('torch version:', torch.__version__)
print('cuda available (ROCm):', torch.cuda.is_available())
if torch.cuda.is_available():
    print('device count:', torch.cuda.device_count())
    print('device 0 name:', torch.cuda.get_device_name(0))

# %%
# Train and run inference
# Note: use 'cuda' for ROCm-enabled PyTorch (maps to HIP)
# !python main.py \
  --image real/images/top-camera05.jpg \
  --output overlay_rocm.jpg \
  --force-regen --force-train \
  --epochs 20 --conf 0.5 \
  --device cuda \
  --grayscale --clahe --contrast-alpha 0.8 --contrast-beta -2 \
  --max-det 30 --train-nms-time 5 \
  --num-train 600 --num-val 120 \
  --real-data real \
  --preprocess-train \
  --save-preprocessed tmp/pre_rocm.jpg
# Out:
# [info] Generating synthetic dataset at data/synth_grid
# [info] copied 58 real images into train set
# [info] preprocessed 1974 images in data/synth_grid/images/train (including augmented alpha variants)
# [info] preprocessed 360 images in data/synth_grid/images/val (including augmented alpha variants)
# [info] Training lightweight YOLO model to detect grid: models/cell_grid.pt
# [W1206 21:45:35.749490675 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.752265737 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.753807383 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.756284711 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.757388290 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.757586773 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.757986396 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.758177712 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.758366776 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.758639888 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.759925495 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.760060304 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.760261329 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.760469054 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.760577086 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.761384860 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.762058661 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.762335169 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.762701177 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.762973685 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.763956688 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.765188086 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.766144536 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.766345600 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.766714876 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.766955044 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.767845364 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.768025117 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.768225917 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.768426516 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.770259507 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.773006067 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.773883310 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.774264637 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.774827944 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775141483 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775209661 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775505954 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775596982 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775624312 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.775909366 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.776049916 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.7.1+rocm7.0.0.git698b58a9 CUDA:0 (AMD Instinct MI300X VF, 196288MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data/synth_grid/synth_grid.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=30, mixup=0.0, mode=train, model=yolov8n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=models, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspace/yolo-train/models/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# [W1206 21:45:35.167669377 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.168837594 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.169601128 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.171205254 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.172220227 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.172402778 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.172821658 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.173059767 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.173360850 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.173808844 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.174875189 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.175017469 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.175240101 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.175465584 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.175614109 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.176414364 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.177018017 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.177308832 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.177703654 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.177993605 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.178987032 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.180281293 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.181022568 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.181244778 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.181640337 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.181914368 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.182651191 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.182795519 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.183017099 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.183226852 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.184912786 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.186605572 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.187143383 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.187487328 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.187943555 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.188298345 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.188348704 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.188667253 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.188768451 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.188796492 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.189047895 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.189146575 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.254426569 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.254763390 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.254941522 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255093486 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255246164 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255388334 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255516565 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255651371 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255800333 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.255934171 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256087478 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256222249 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256360582 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256487683 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256644921 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256775097 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.256906558 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257038313 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257169773 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257310117 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257443602 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257643244 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257778698 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.257925796 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258086692 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258228253 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258475621 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258696131 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258844795 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.258977199 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259110621 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259298849 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259430209 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259556165 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259683458 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259827587 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.259975831 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260141947 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260277542 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260414117 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260538305 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260696157 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260841331 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.260991963 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261144285 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261289921 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261436426 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261574024 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261714072 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261853097 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.261986945 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262125201 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262278776 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262410461 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262543772 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262688445 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262818033 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.262954290 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.263112787 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.263231492 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.263364179 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.263514732 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.263631681 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W1206 21:45:35.264133898 NNPACK.cpp:57] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv8n summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2879.7±1221.5 MB/s, size: 90.5 KB)
# train: Scanning /workspace/yolo-train/data/synth_grid/labels/train... 1974 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1974/1974 4.0Kit/s 0.5s0.1s
# train: New cache created: /workspace/yolo-train/data/synth_grid/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2584.6±1925.0 MB/s, size: 115.3 KB)
# val: Scanning /workspace/yolo-train/data/synth_grid/labels/val... 360 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 360/360 938.0it/s 0.4s0.3s
# val: New cache created: /workspace/yolo-train/data/synth_grid/labels/val.cache
# Plotting labels to /workspace/yolo-train/models/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /workspace/yolo-train/models/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.45G      3.222      3.145      3.558        151        640: 100% ━━━━━━━━━━━━ 124/124 9.4it/s 13.2s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 16.1it/s 0.7s0.2s
#                    all        360       5442      0.686      0.411      0.482      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.61G      1.129      0.982      1.525        117        640: 100% ━━━━━━━━━━━━ 124/124 12.5it/s 9.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 14.6it/s 0.8s0.2s
#                    all        360       5442      0.977      0.782      0.837      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.63G     0.8105      0.689      1.177        118        640: 100% ━━━━━━━━━━━━ 124/124 13.1it/s 9.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 16.4it/s 0.7s0.2s
#                    all        360       5442      0.981      0.815      0.872      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.64G     0.6834     0.6024      1.068        121        640: 100% ━━━━━━━━━━━━ 124/124 13.0it/s 9.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 16.9it/s 0.7s0.1s
#                    all        360       5442      0.924      0.886      0.954      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.66G     0.5924     0.5319      1.003        401        640: 74% ━━━━━━━━╸─── 92/124 12.6it/s 7.5s<2.5s

# %%
# Show inference result
from PIL import Image
Image.open('overlay_rocm.jpg')

# %%
# Verify all real images and save predictions to tmp/preds
# Also warn if no IoU>0.3 match per class vs label
import cv2
import numpy as np
from pathlib import Path
from ultralytics import YOLO
from main import apply_preprocess

weights = Path('models/cell_grid.pt')
model = YOLO(str(weights))
img_dir = Path('real/images')
lbl_dir = Path('real/labels')
out_dir = Path('tmp/preds')
out_dir.mkdir(parents=True, exist_ok=True)

def yolo_to_xyxy(label_path, shape):
    h, w = shape[:2]
    boxes = []
    for line in Path(label_path).read_text().splitlines():
        if not line.strip():
            continue
        cls, xc, yc, bw, bh = map(float, line.split())
        x0 = (xc - bw / 2) * w
        y0 = (yc - bh / 2) * h
        x1 = (xc + bw / 2) * w
        y1 = (yc + bh / 2) * h
        boxes.append((int(cls), np.array([x0, y0, x1, y1], dtype=np.float32)))
    return boxes

def iou(box1, box2):
    xa = max(box1[0], box2[0]); ya = max(box1[1], box2[1])
    xb = min(box1[2], box2[2]); yb = min(box1[3], box2[3])
    inter = max(0, xb - xa) * max(0, yb - ya)
    area1 = max(0, box1[2]-box1[0]) * max(0, box1[3]-box1[1])
    area2 = max(0, box2[2]-box2[0]) * max(0, box2[3]-box2[1])
    union = area1 + area2 - inter + 1e-6
    return inter / union

for img_path in img_dir.glob('**/*'):
    if img_path.suffix.lower() not in ('.jpg', '.jpeg', '.png'):
        continue
    try:
        img = cv2.imread(str(img_path))
        img = apply_preprocess(img, grayscale=True, clahe=True, contrast_alpha=0.8, contrast_beta=-2)
        res = model.predict(source=img, conf=0.5, imgsz=640, device='cuda', verbose=False)
        cv2.imwrite(str(out_dir / img_path.name), res[0].plot())
        lbl_path = lbl_dir / img_path.relative_to(img_dir)
        lbl_path = lbl_path.with_suffix('.txt')
        if lbl_path.exists():
            gt = yolo_to_xyxy(lbl_path, img.shape)
            preds = [(int(b.cls.item()), b.xyxy[0].cpu().numpy()) for b in res[0].boxes]
            for cls, gt_box in gt:
                matches = [p for p in preds if p[0] == cls and iou(gt_box, p[1]) > 0.3]
                if not matches:
                    print(f"[warn] mismatch {img_path.name}: missing cls {cls}")
    except Exception as e:
        print(f"[error] {img_path}: {e}")

print('done')
